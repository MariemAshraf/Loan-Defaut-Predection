# %%
import pandas as pd 
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import matplotlib

# %%
df = pd.read_csv('/Users/mariemashraf/Documents/DS/168733-383865-bundle-archive/train.csv')

# %%
df.shape
# Out:
# (233154, 41)

# %%
df.head(5000)
# Out:
#       UniqueID  disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# 0       420825             50578       58400  89.55         67        22807
# 1       537409             47145       65550  73.23         67        22807
# 2       417566             53278       61360  89.63         67        22807
# 3       624493             57513       66113  88.48         67        22807
# 4       539055             52378       60300  88.39         67        22807
# ...        ...               ...         ...    ...        ...          ...
# 9995    590961             53463       82000  67.20          8        22200
# 9996    557730             77901      101838  78.56          8        18052
# 9997    542045             81686      149700  56.11          8        18234
# 9998    542670             65090       75950  88.22          8        14754
# 9999    558888            124540      150100  84.94          8        18234
#
# ...

# %%
frame = pd.DataFrame(df.head(5000))
frame.to_csv('/Users/mariemashraf/Documents/DS/168733-383865-bundle-archive/FrameSaple.csv')

# %%
frame.shape
# Out:
# (5000, 41)
